# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df_angle = pd.read_csv('10_50_angle.csv', index_col = 0)
df_trans = pd.read_csv('10_50_trans.csv', index_col = 0)
df_trans = df_trans*100

# %%
df_trans
# Out:
#          x      y       z
# 0   -4.680 -1.106  36.840
# 1   -4.681 -1.093  36.912
# 2   -4.680 -1.106  36.840
# 3   -4.681 -1.093  36.912
# 4   -4.681 -1.105  36.929
# ..     ...    ...     ...
# 127 -4.684 -1.015  36.799
# 128 -4.685 -1.023  36.777
# 129 -4.685 -1.023  36.777
# 130 -4.685 -1.036  36.707
# 131 -4.685 -1.023  36.777
#
# [132 rows x 3 columns]

# %%
df_angle.describe()
# Out:
#             pitch         yaw        roll
# count  132.000000  132.000000  132.000000
# mean   -25.291785   -3.004877   -0.991266
# std      0.251085    0.189270    0.093710
# min    -25.954878   -3.558026   -1.144023
# 25%    -25.456003   -3.107554   -1.037897
# 50%    -25.257828   -3.024296   -1.016937
# 75%    -25.082282   -2.846559   -0.928342
# max    -24.912303   -2.744628   -0.795470

# %%
df_trans.describe()
# Out:
#                 x           y           z
# count  132.000000  132.000000  132.000000
# mean    -4.679856   -1.047424   36.786924
# std      0.011832    0.023857    0.048395
# min     -4.705000   -1.106000   36.674000
# 25%     -4.685000   -1.066000   36.763750
# 50%     -4.682000   -1.043000   36.780000
# 75%     -4.679000   -1.031000   36.809000
# max     -4.642000   -1.015000   36.929000

# %%
label = ['pitch','yaw','roll']

# %%
plt.plot(df_angle['pitch'], label='pitch')
plt.plot(df_angle['yaw'], label='yaw')
plt.plot(df_angle['roll'], label='roll')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
plt.plot(df_trans['x'], label='x distance')
plt.plot(df_trans['y'], label='y distance')
plt.plot(df_trans['z'], label='z distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_angle['yaw'], label='yaw', color='#ff7f0e')
#plt.plot(df_angle['roll'], label='roll', color='#2ca02c')
plt.plot(df_angle['pitch'], label='pitch')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_trans['z'], label='z distance',color='#2ca02c')
plt.plot(df_trans['x'], label='x distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend()
plt.show()
