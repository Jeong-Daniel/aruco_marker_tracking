# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df_angle = pd.read_csv('10_100_angle.csv', index_col = 0)
df_trans = pd.read_csv('10_100_trans.csv', index_col = 0)
df_trans = df_trans*100

# %%
df_trans
# Out:
#          x       y       z
# 0    3.489  15.940  70.771
# 1    3.481  15.905  70.691
# 2    3.489  15.940  70.771
# 3    3.489  15.940  70.771
# 4    3.489  15.940  70.771
# ..     ...     ...     ...
# 156  3.383  15.934  69.874
# 157  3.445  16.015  70.365
# 158  3.445  16.015  70.365
# 159  3.448  16.044  70.402
# 160  3.443  16.101  70.635
#
# [161 rows x 3 columns]

# %%
df_angle.describe()
# Out:
#             pitch         yaw        roll
# count  161.000000  161.000000  161.000000
# mean   -33.604003    5.969412   -4.033473
# std      0.886838    0.348933    0.210780
# min    -35.521283    4.826335   -4.590300
# 25%    -34.388554    5.803213   -4.195861
# 50%    -33.629837    6.051810   -4.022349
# 75%    -32.862811    6.112844   -3.925236
# max    -31.710796    6.785711   -3.347047

# %%
df_trans.describe()
# Out:
#                 x           y           z
# count  161.000000  161.000000  161.000000
# mean     3.440037   15.955839   70.296913
# std      0.025345    0.071522    0.211626
# min      3.379000   15.752000   69.823000
# 25%      3.417000   15.911000   70.177000
# 50%      3.445000   15.971000   70.358000
# 75%      3.449000   16.015000   70.411000
# max      3.498000   16.101000   70.771000

# %%
label = ['pitch','yaw','roll']

# %%
plt.plot(df_angle['pitch'], label='pitch')
plt.plot(df_angle['yaw'], label='yaw')
plt.plot(df_angle['roll'], label='roll')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
plt.plot(df_trans['x'], label='x distance')
plt.plot(df_trans['y'], label='y distance')
plt.plot(df_trans['z'], label='z distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_angle['yaw'], label='yaw', color='#ff7f0e')
#plt.plot(df_angle['roll'], label='roll', color='#2ca02c')
plt.plot(df_angle['pitch'], label='pitch')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_trans['z'], label='z distance',color='#2ca02c')
plt.plot(df_trans['x'], label='x distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend()
plt.show()
