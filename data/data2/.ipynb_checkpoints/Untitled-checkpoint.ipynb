# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df_angle = pd.read_csv('10_50_angle.csv', index_col = 0)
df_trans = pd.read_csv('10_50_trans.csv', index_col = 0)
df_trans = df_trans*100

# %%
df_trans = df_trans[20:100]
df_angle = df_angle[20:100]

# %%
df_angle.describe()
# Out:
#            pitch        yaw       roll
# count  80.000000  80.000000  80.000000
# mean  -33.833542  -2.565560  -1.040334
# std     0.642919   0.484509   0.216296
# min   -34.863813  -3.469893  -1.343193
# 25%   -34.384556  -2.963250  -1.267702
# 50%   -33.858221  -2.696694  -1.014184
# 75%   -33.317198  -2.061127  -0.900438
# max   -32.828222  -1.469578  -0.653564

# %%
df_trans.describe()
# Out:
#                x          y         z
# count  80.000000  80.000000  80.00000
# mean   -7.054725   8.434638  73.81045
# std     0.027153   0.049340   0.15476
# min    -7.119000   8.360000  73.57400
# 25%    -7.075250   8.397000  73.62100
# 50%    -7.073000   8.421000  73.85200
# 75%    -7.024000   8.480000  73.91300
# max    -7.023000   8.542000  74.13500

# %%
label = ['pitch','yaw','roll']

# %%
plt.plot(df_angle['pitch'], label='pitch')
plt.plot(df_angle['yaw'], label='yaw')
plt.plot(df_angle['roll'], label='roll')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
plt.plot(df_trans['x'], label='x distance')
plt.plot(df_trans['y'], label='y distance')
plt.plot(df_trans['z'], label='z distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_angle['yaw'], label='yaw', color='#ff7f0e')
#plt.plot(df_angle['roll'], label='roll', color='#2ca02c')
plt.plot(df_angle['pitch'], label='pitch')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_trans['z'], label='z distance',color='#2ca02c')
plt.plot(df_trans['x'], label='x distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend()
plt.show()
