# %%
import matplotlib.pyplot as plt
import os
import cv2
# %matplotlib inline

# %%
# rgb 이미지 불러오기
rgb_image = cv2.imread('26_20-02-57.png')

# rgb 이미지 보기
cv2.imshow('rgb_image', rgb_image)
cv2.waitKey(0)
# Out:
# -1

# %%
bgr_img_array = cv2.imread("26_20-02-57.png")
rgb_img_array = cv2.cvtColor(bgr_img_array, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(rgb_img_array)
plt.show()

# %%
src = cv2.imread("26_20-02-57.png", cv2.IMREAD_COLOR)
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)

cv2.imshow("h", h)
cv2.imshow("s", s)
cv2.imshow("v", v)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread("26_20-02-57.png", cv2.IMREAD_COLOR)
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)

h, s, v = cv2.split(hsv)

fig = plt.figure()
rows = 1
cols = 3

gray = cv2.cvtColor(temp, cv2.COLOR_RGB2GRAY)

ax1 = fig.add_subplot(rows, cols, 1)
ax1.imshow(h, cmap='gray')
ax1.set_title('Hue')
 
ax2 = fig.add_subplot(rows, cols, 2)
ax2.imshow(s, cmap='gray')
ax2.set_title('Saturation')

ax3 = fig.add_subplot(rows, cols, 3)
ax3.imshow(v, cmap='gray')
ax3.set_title('Value')

plt.show()
plt.figure(figsize=(20, 5))

# %%
src = cv2.imread("26_20-02-57.png", cv2.IMREAD_COLOR)
hsv = cv2.cvtColor(src, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)
dst = cv2.GaussianBlur(v, (0, 0), 1)
#ret, thr1 = cv2.threshold(dst, 127,255, cv2.THRESH_BINARY)
#ret, thr1 = cv2.threshold(dst, 127,255, cv2.THRESH_TRUNC)
#ret, thr1 = cv2.threshold(dst, 127,255, cv2.THRESH_TOZERO)
cv2.imshow('temp', thr1)
cv2.waitKey()
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt 

img = cv2.imread("26_20-02-57.png",0)

# global thresholding
ret1, th1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

ret2, th2 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blur = cv2.GaussianBlur(img,(5,5),0)

ret3, th3 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# plot all the images and their histograms
images = [img, 0, th1, img, 0, th2, blur, 0, th3]

titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)', 'Original Noisy Image','Histogram',"Otsu's Thresholding", 'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]

for i in xrange(3):
	plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
	plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
	plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
	plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
	plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
	plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9bebeb83ca05> in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3 from matplotlib import pyplot as plt
#       4
#       5 img = cv2.imread('images/noise.png',0)
#
# ModuleNotFoundError: No module named 'cv2'
