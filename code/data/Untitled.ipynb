# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df_angle = pd.read_csv('20_20-06-24_angle.csv', index_col = 0)
df_trans = pd.read_csv('20_20-06-24_trans.csv', index_col = 0)
df_trans = df_trans*100

# %%
df_trans
# Out:
#         x      y       z
# 0  -8.434  8.686  48.238
# 1  -8.436  8.681  48.224
# 2  -8.417  8.682  48.289
# 3  -8.422  8.701  48.255
# 4  -8.412  8.681  48.199
# ..    ...    ...     ...
# 92 -8.410  8.674  47.967
# 93 -8.402  8.680  47.961
# 94 -8.426  8.681  47.986
# 95 -8.394  8.686  47.955
# 96 -8.406  8.682  48.049
#
# [97 rows x 3 columns]

# %%
df_angle.describe()
# Out:
#            pitch        yaw       roll
# count  97.000000  97.000000  97.000000
# mean   -1.215650   1.097016  -3.656526
# std     0.389370   0.381801   0.086372
# min    -1.933313   0.090316  -3.854501
# 25%    -1.561470   0.885823  -3.731227
# 50%    -1.231153   1.141220  -3.654348
# 75%    -0.937373   1.276066  -3.588923
# max    -0.665440   1.790601  -3.477803

# %%
df_trans.describe()
# Out:
#                x          y          z
# count  97.000000  97.000000  97.000000
# mean   -8.419041   8.727711  48.205629
# std     0.015700   0.027252   0.107770
# min    -8.458000   8.674000  47.955000
# 25%    -8.430000   8.711000  48.153000
# 50%    -8.417000   8.733000  48.238000
# 75%    -8.407000   8.740000  48.285000
# max    -8.389000   8.793000  48.361000

# %%
label = ['pitch','yaw','roll']

# %%
plt.plot(df_angle['pitch'], label='pitch')
plt.plot(df_angle['yaw'], label='yaw')
plt.plot(df_angle['roll'], label='roll')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
plt.plot(df_trans['x'], label='x distance')
plt.plot(df_trans['y'], label='y distance')
plt.plot(df_trans['z'], label='z distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_angle['yaw'], label='yaw', color='#ff7f0e')
#plt.plot(df_angle['roll'], label='roll', color='#2ca02c')
plt.plot(df_angle['pitch'], label='pitch')
plt.ylabel('angle(degree)')
plt.xlabel('횟수')
plt.legend(loc='upper right', frameon=True) 
plt.show()

# %%
#plt.plot(df_trans['z'], label='z distance',color='#2ca02c')
plt.plot(df_trans['x'], label='x distance')
plt.xlabel('횟수')
plt.ylabel('distance(cm)')
plt.legend()
plt.show()
